# %% [markdown]
# <a href="https://colab.research.google.com/github/nisa0658/nisa0658/blob/main/me1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import cv2

img = cv2.imread("/content/Screen Shot 14.09.2024 at 15.40.png")
cv2_imshow(img)

img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=RGB size=632x629>
# <PIL.Image.Image image mode=L size=632x629>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e5d93709-f31d-4aaf-acde-16c1101797f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5d93709-f31d-4aaf-acde-16c1101797f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
resim = cv2.imread("/content/arka_plan_resmi.jpg")
width,height,channels = img.shape

print(width,height,channels)

# %%
# !pip install rembg

# %%
# !pip install Pillow==9.0.0

# %%
from rembg import remove
from goggle.colab.patches import cv2_imshow

girisresmi = "/content/Screen Shot 14.09.2024 at 15.40.png"
cikisresmi = "content/cıktı.jpeg"

with open(girisresmi,"rb") as f:
  with open(cikisresmi,"wb") as o:
    input = f.read()
    output = remove(input)
    o.write(output)

cv2_imshow(cv2.imread(''))

# %%
def change_back(background, img):

    """ Görüntülerin siyah arka planını başka bir görüntüyle değiştiren işlev.

 İki bağımsız değişkeni kabul eder: arka plan görüntüsü (arka plan) ve görüntünün kendisi (img).

 İşlev, görüntünün sol üst köşesinden başlayacaktır. Tüm siyah pikselleri arayacaktır (0 değeri ile)

 ve arka plan görüntüsünün pikselleriyle değiştirecektir"""

    x, y = 0, 0

    background = cv2.resize(background, (img.shape[1], img.shape[0]), interpolation = cv2.INTER_AREA)

    res = np.copy(background)

    place = res[y: y + img.shape[0], x: x + img.shape[1]]

    a = img[..., 3:].repeat(3, axis=2).astype('uint16')

    place[...] = (place.astype('uint16') * (255 - a) // 255) + img[..., :3].astype('uint16') * a // 255

    return res

# %%
back = cv2.imread("/content/arka_plan_resmi.jpg")
img = cv2.imread("")

change back(back,img)
cv2_imshow(sonuc)
